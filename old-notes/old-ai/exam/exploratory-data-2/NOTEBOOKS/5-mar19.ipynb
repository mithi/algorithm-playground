# %%
from explore import explore_tsv, months, paths, top_from_search, top_articles

# %%
f = paths[4]
              
df = explore_tsv(f)
top_from_search(df)[:25]
# Out:
#                                                        n
# curr
# Luke_Perry                                        527085
# Freddie_Mercury                                   320180
# Moldavie                                          271502
# Agnès_Varda                                       243420
# PNL_(groupe)                                      239899
# Signe_du_zodiaque                                 233757
# Abdelaziz_Bouteflika                              229428
# Cristiano_Ronaldo                                 229421
# Franck_Gastambide                                 225904
# Kylian_Mbappé                                     213001
# Les_Bracelets_rouges_(série_télévisée_française)  212734
# Raphaël_Glucksmann                                212423
# Lionel_Messi                                      196571
# Jenifer                                           190477
# Umbrella_Academy_(série_télévisée)                188480
# ...

# %%
top_articles(df)[:25]
# Out:
#                                                         n
# curr
# -                                                 1093233
# Luke_Perry                                         695812
# France                                             599467
# Kayden_Boche                                       457675
# Freddie_Mercury                                    431682
# Moldavie                                           347422
# Cristiano_Ronaldo                                  329485
# Agnès_Varda                                        309647
# Franck_Gastambide                                  301167
# Abdelaziz_Bouteflika                               292127
# Comptabilité                                       286191
# Lionel_Messi                                       285760
# Signe_du_zodiaque                                  267697
# Kylian_Mbappé                                      267416
# Raphaël_Glucksmann                                 266199
# ...
