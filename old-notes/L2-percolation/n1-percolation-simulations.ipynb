# %%
from percolation_grid import PercolationGrid, PercolationStats

# %%
def print_title(title):
  print("----------------------------")
  print(title)
  print("----------------------------")

def print_spacer():
  print()
  print("............................................")
  print()

# %% [markdown]
# ## Sample visualization
# - https://www.youtube.com/watch?v=4pYvVtO1WxI
#
# ## Specifications
# - http://coursera.cs.princeton.edu/algs4/assignments/percolation.html

# %%
PercolationExperiment= PercolationStats()

# %%
PercolationExperiment.run_simulations(n = 5, t = 100)
# Out:
# {'mean': 0.608,
#  'stdev': 0.11952769004238595,
#  'low95': 0.5845725727516924,
#  'high95': 0.6314274272483076}

# %%
print_title(" 2 x 2 grid, 10,000 trials")
_ = PercolationExperiment.run_simulations(n = 2, t = 10000, print_stats = True)

print_title(" 2 x 2 grid, 100,000 trials")
_ = PercolationExperiment.run_simulations(n = 2, t = 100000, print_stats = True)

print_spacer()

print_title(" 5 x 5 grid, 200 trials")
_ = PercolationExperiment.run_simulations(n = 5, t = 200, print_stats = True)

print_title(" 5 x 5 grid, 500 trials")
_ = PercolationExperiment.run_simulations(n = 5, t = 500, print_stats = True)

print_spacer()
# Out:
# ----------------------------
#  2 x 2 grid, 10,000 trials
# ----------------------------
# mean : 0.6666
# stdev : 0.11788057339086154
# low95 : 0.6642895407615391
# high95 : 0.6689104592384608
# ----------------------------
#  2 x 2 grid, 100,000 trials
# ----------------------------
# mean : 0.666035
# stdev : 0.11807314761486574
# low95 : 0.6653031750491423
# high95 : 0.6667668249508578
#
# ............................................
#
# ----------------------------
#  5 x 5 grid, 200 trials
# ----------------------------
# mean : 0.5934
# stdev : 0.10079303637109323
# low95 : 0.5794307978551811
# high95 : 0.6073692021448189
# ----------------------------
#  5 x 5 grid, 500 trials
# ----------------------------
# mean : 0.5935199999999999
# stdev : 0.09807572224862368
# low95 : 0.5849232839098998
# high95 : 0.6021167160901001
#
# ............................................

# %%
print_title(" 20 x 20 grid, 50 trials")
_ = PercolationExperiment.run_simulations(n = 20, t = 50, print_stats = True)

print_title(" 20 x 20 grid, 100 trials")
_ = PercolationExperiment.run_simulations(n = 20, t = 100, print_stats = True)

print_title(" 20 x 20 grid, 200 trials")
_ = PercolationExperiment.run_simulations(n = 20, t = 200, print_stats = True)

print_spacer()

print_title(" 50 x 50 grid, 50 trials")
_ = PercolationExperiment.run_simulations(n = 50, t = 50, print_stats = True)

print_title(" 50 x 50 grid, 50 trials")
_ = PercolationExperiment.run_simulations(n = 50, t = 50, print_stats = True)

print_title(" 50 x 50 grid, 100 trials")
_ = PercolationExperiment.run_simulations(n = 50, t = 100, print_stats = True)

print_title(" 50 x 50 grid, 100 trials")
_ = PercolationExperiment.run_simulations(n = 50, t = 100, print_stats = True)

print_title(" 50 x 50 grid, 200 trials")
_ = PercolationExperiment.run_simulations(n = 50, t = 200, print_stats = True)

print_title(" 50 x 50 grid, 200 trials")
_ = PercolationExperiment.run_simulations(n = 50, t = 200, print_stats = True)

print_spacer()

print_title(" 100 x 100 grid, 50 trials")
_ = PercolationExperiment.run_simulations(n = 100, t = 50, print_stats = True)

print_title(" 100 x 100 grid, 50 trials")
_ = PercolationExperiment.run_simulations(n = 100, t = 50, print_stats = True)

print_title(" 100 x 100 grid, 100 trials")
_ = PercolationExperiment.run_simulations(n = 100, t = 100, print_stats = True)

print_title(" 100 x 100 grid, 100 trials")
_ = PercolationExperiment.run_simulations(n = 100, t = 100, print_stats = True)

print_title(" 100 x 100 grid, 200 trials")
_ = PercolationExperiment.run_simulations(n = 100, t = 200, print_stats = True)

print_title(" 100 x 100 grid, 200 trials")
_ = PercolationExperiment.run_simulations(n = 100, t = 200, print_stats = True)


print_spacer()

print_title(" 200 x 200 grid, 50 trials")
_ = PercolationExperiment.run_simulations(n = 200, t = 50, print_stats = True)

print_title(" 200 x 200 grid, 50 trials")
_ = PercolationExperiment.run_simulations(n = 200, t = 50, print_stats = True)

print_title(" 200 x 200 grid, 100 trials")
_ = PercolationExperiment.run_simulations(n = 200, t = 100, print_stats = True)

print_title(" 200 x 200 grid, 100 trials")
_ = PercolationExperiment.run_simulations(n = 200, t = 100, print_stats = True)

print_title(" 200 x 200 grid, 200 trials")
_ = PercolationExperiment.run_simulations(n = 200, t = 200, print_stats = True)

print_title(" 200 x 200 grid, 200 trials")
_ = PercolationExperiment.run_simulations(n = 200, t = 200, print_stats = True)

print_spacer()

print_title(" 200 x 200 grid, 50 trials")
_ = PercolationExperiment.run_simulations(n = 200, t = 50, print_stats = True)

print_title(" 200 x 200 grid, 50 trials")
_ = PercolationExperiment.run_simulations(n = 200, t = 50, print_stats = True)

print_title(" 200 x 200 grid, 100 trials")
_ = PercolationExperiment.run_simulations(n = 200, t = 100, print_stats = True)

print_title(" 200 x 200 grid, 100 trials")
_ = PercolationExperiment.run_simulations(n = 200, t = 100, print_stats = True)

print_title(" 200 x 200 grid, 200 trials")
_ = PercolationExperiment.run_simulations(n = 200, t = 200, print_stats = True)

print_title(" 200 x 200 grid, 200 trials")
_ = PercolationExperiment.run_simulations(n = 200, t = 200, print_stats = True)
# Out:
# ----------------------------
#  20 x 20 grid, 50 trials
# ----------------------------
# mean : 0.5901000000000001
# stdev : 0.04765136998266147
# low95 : 0.576891714115753
# high95 : 0.6033082858842471
# ----------------------------
#  20 x 20 grid, 100 trials
# ----------------------------
# mean : 0.5975750000000001
# stdev : 0.04579468756407133
# low95 : 0.5885992412374421
# high95 : 0.606550758762558
# ----------------------------
#  20 x 20 grid, 200 trials
# ----------------------------
# mean : 0.58715
# stdev : 0.046809675587886915
# low95 : 0.5806625099494659
# high95 : 0.593637490050534
#
# ............................................
#
# ----------------------------
#  50 x 50 grid, 50 trials
# ----------------------------
# mean : 0.598168
# stdev : 0.024744782505095694
# low95 : 0.5913090962247309
# high95 : 0.6050269037752691
# ----------------------------
#  50 x 50 grid, 50 trials
# ----------------------------
# mean : 0.589744
# stdev : 0.025673715296833398
# ...
