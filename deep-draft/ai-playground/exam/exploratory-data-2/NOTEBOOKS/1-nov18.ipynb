# %%
from explore import explore_tsv, months, paths, top_from_search, top_articles
import matplotlib as plt
#import seaborn as sns

# %%
for month, path in zip(months, paths):
    df = explore_tsv(path)
    print("| month: {:5} | rows: {:7d} | clicks: {:10d} |".format(month, df['n'].count(), df.n.sum()))
# Out:
# | month: Nov '18 | rows: 3648841 | clicks:  592140546 |
# | month: Dec '18 | rows: 3605414 | clicks:  553715340 |
# | month: Jan '19 | rows: 3840887 | clicks:  607900426 |
# | month: Feb '19 | rows: 3497999 | clicks:  519465272 |
# | month: Mar '19 | rows: 3842618 | clicks:  583624473 |

# %%
f = paths[0]
df = explore_tsv(f)

# %%
top_articles(df)[:25]
# Out:
#                                                           n
# curr
# -                                                   1151650
# Freddie_Mercury                                     1009215
# France                                               695139
# La_Vérité_sur_l'affaire_Harry_Quebert                661427
# Attentats_du_13_novembre_2015_en_France              507898
# Stan_Lee                                             484610
# Carlos_Ghosn                                         433640
# Guerre_civile_syrienne                               430221
# Première_Guerre_mondiale                             429364
# Queen                                                419876
# Victor_Hugo                                          410806
# Technologies_de_l'information_et_de_la_communic...   332742
# Propylène_glycol                                     319302
# Black_Friday_(shopping)                              310179
# Philippe_Pétain                                      305529
# ...

# %%
top_from_search(df)[:25]
# Out:
#                                                          n
# curr
# Freddie_Mercury                                     730379
# La_Vérité_sur_l'affaire_Harry_Quebert               592669
# Stan_Lee                                            388250
# Carlos_Ghosn                                        351895
# Première_Guerre_mondiale                            325652
# Victor_Hugo                                         321662
# Queen                                               304329
# Black_Friday_(shopping)                             271400
# Philippe_Pétain                                     245926
# Armistice_de_1918                                   223836
# Angèle_(chanteuse)                                  218893
# Mai_68                                              213560
# Patrick_Bruel                                       205837
# Harry_Potter_(série_de_films)                       201455
# Thanksgiving_(États-Unis)                           199155
# ...
