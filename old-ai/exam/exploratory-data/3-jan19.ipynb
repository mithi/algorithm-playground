# %%
from explore import explore_tsv, months, paths, top_from_search, top_articles

# %%
f = paths[2]
              
df = explore_tsv(f)
top_from_search(df)[:25]
# Out:
#                                                      n
# curr
# Emiliano_Sala                                   767670
# Bilal_Hassani                                   387874
# Championnat_du_monde_masculin_de_handball_2019  372017
# Christophe_Dettinger                            365050
# Che_Guevara                                     359355
# Michel_Legrand                                  334734
# Freddie_Mercury                                 332669
# You_(série_télévisée)                           318855
# Sex_Education                                   257460
# Marlène_Schiappa                                250222
# Signe_du_zodiaque                               228247
# Chantal_Jouanno                                 220060
# Titans_(série_télévisée,_2018)                  206656
# Glass_(film)                                    191005
# Carlos_Ghosn                                    186812
# Galette_des_rois                                181636
# ...

# %%
top_articles(df)[:25]
# Out:
#                                                       n
# curr
# -                                               1287485
# Emiliano_Sala                                    926301
# Championnat_du_monde_masculin_de_handball_2019   491633
# Kayden_Boche                                     466861
# France                                           460802
# Christophe_Dettinger                             450161
# Freddie_Mercury                                  446751
# Bilal_Hassani                                    445388
# Che_Guevara                                      428967
# Michel_Legrand                                   427701
# You_(série_télévisée)                            348452
# Comptabilité                                     320175
# Marlène_Schiappa                                 307730
# Sex_Education                                    299922
# Chantal_Jouanno                                  272306
# Signe_du_zodiaque                                262979
# ...
